# %%
import pandas as pd

# %%
data=pd.read_csv("D:\\DATA_science\\Data_sets\\Multilinear_Reg\\Toyoto_Corrola.csv")
data.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3  ÊTOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#       KM  HP  Doors  Cylinders  Gears  Weight
# 0  46986  90      3          4      5    1165
# 1  72937  90      3          4      5    1165
# 2  41711  90      3          4      5    1165
# 3  48000  90      3          4      5    1165
# 4  38500  90      3          4      5    1170

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         1436 non-null   int64
#  1   Model      1436 non-null   object
#  2   Price      1436 non-null   int64
#  3   Age_08_04  1436 non-null   int64
#  4   KM         1436 non-null   int64
#  5   HP         1436 non-null   int64
#  6   Doors      1436 non-null   int64
#  7   Cylinders  1436 non-null   int64
#  8   Gears      1436 non-null   int64
#  9   Weight     1436 non-null   int64
# dtypes: int64(9), object(1)
# memory usage: 112.3+ KB

# %%
data.isnull().sum()
# Out:
# Id           0
# Model        0
# Price        0
# Age_08_04    0
# KM           0
# HP           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %%
data.corr()
# Out:
#                  Id     Price  Age_08_04        KM        HP     Doors  \
# Id         1.000000 -0.738250   0.906132  0.273298 -0.109375 -0.130207
# Price     -0.738250  1.000000  -0.876590 -0.569960  0.314990  0.185326
# Age_08_04  0.906132 -0.876590   1.000000  0.505672 -0.156622 -0.148359
# KM         0.273298 -0.569960   0.505672  1.000000 -0.333538 -0.036197
# HP        -0.109375  0.314990  -0.156622 -0.333538  1.000000  0.092424
# Doors     -0.130207  0.185326  -0.148359 -0.036197  0.092424  1.000000
# Cylinders       NaN       NaN        NaN       NaN       NaN       NaN
# Gears     -0.043343  0.063104  -0.005364  0.015023  0.209477 -0.160141
# Weight    -0.414500  0.581198  -0.470253 -0.028598  0.089614  0.302618
#
#            Cylinders     Gears    Weight
# Id               NaN -0.043343 -0.414500
# Price            NaN  0.063104  0.581198
# Age_08_04        NaN -0.005364 -0.470253
# KM               NaN  0.015023 -0.028598
# HP               NaN  0.209477  0.089614
# ...

# %%
data1=data1.drop(['Id','Model'],axis=1)
data1.head()
# Out:
#    Price  Age_08_04     KM  HP  Doors  Cylinders  Gears  Weight
# 0  13500         23  46986  90      3          4      5    1165
# 1  13750         23  72937  90      3          4      5    1165
# 2  13950         24  41711  90      3          4      5    1165
# 3  14950         26  48000  90      3          4      5    1165
# 4  13750         30  38500  90      3          4      5    1170

# %%
data1.corr()
# Out:
#                  Id     Price  Age_08_04        KM        HP     Doors  \
# Id         1.000000 -0.738250   0.906132  0.273298 -0.109375 -0.130207
# Price     -0.738250  1.000000  -0.876590 -0.569960  0.314990  0.185326
# Age_08_04  0.906132 -0.876590   1.000000  0.505672 -0.156622 -0.148359
# KM         0.273298 -0.569960   0.505672  1.000000 -0.333538 -0.036197
# HP        -0.109375  0.314990  -0.156622 -0.333538  1.000000  0.092424
# Doors     -0.130207  0.185326  -0.148359 -0.036197  0.092424  1.000000
# Cylinders       NaN       NaN        NaN       NaN       NaN       NaN
# Gears     -0.043343  0.063104  -0.005364  0.015023  0.209477 -0.160141
# Weight    -0.414500  0.581198  -0.470253 -0.028598  0.089614  0.302618
#
#            Cylinders     Gears    Weight
# Id               NaN -0.043343 -0.414500
# Price            NaN  0.063104  0.581198
# Age_08_04        NaN -0.005364 -0.470253
# KM               NaN  0.015023 -0.028598
# HP               NaN  0.209477  0.089614
# ...

# %%
import seaborn as sns

# %%
sns.set_style(style='darkgrid')
sns.pairplot(data1)

# %%
data1.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'HP', 'Doors', 'Cylinders', 'Gears',
#        'Weight'],
#       dtype='object')

# %%
import statsmodels.formula.api as smf
model=smf.ols('Price~Age_08_04+KM+HP+Doors+Gears+Weight+Cylinders',data=data1).fit()

# %%
model.params
# Out:
# Intercept    -410.845504
# Age_08_04    -122.242218
# KM             -0.019994
# HP             28.350149
# Doors          -9.680229
# Gears         622.282925
# Weight         18.609651
# Cylinders   -1643.382016
# dtype: float64

# %%
(model.tvalues,'\n',model.pvalues)
# Out:
# (Intercept    -5.323309
#  Age_08_04   -46.728942
#  KM          -16.542560
#  HP           10.842418
#  Doors        -0.242055
#  Gears         3.152234
#  Weight       22.446903
#  Cylinders    -5.323309
#  dtype: float64,
#  '\n',
#  Intercept     1.181900e-07
#  Age_08_04    4.387432e-290
#  KM            2.238900e-56
#  HP            2.231791e-26
#  Doors         8.087723e-01
#  Gears         1.653931e-03
#  Weight        7.856458e-96
#  Cylinders     1.181900e-07
#  dtype: float64)

# %%
(model.rsquared,model.rsquared_adj)
# Out:
# (0.8628024511073656, 0.8622263942190831)

# %%
model1=smf.ols('Price~Age_08_04+KM+HP+Gears+Weight+Cylinders',data=data1).fit()

# %%
model1.params
# Out:
# Intercept    -412.166307
# Age_08_04    -122.243676
# KM             -0.019996
# HP             28.282948
# Gears         631.543519
# Weight         18.557373
# Cylinders   -1648.665230
# dtype: float64

# %%
model1.tvalues,'\n',model1.pvalues
# Out:
# (Intercept    -5.355584
#  Age_08_04   -46.745013
#  KM          -16.550661
#  HP           10.881794
#  Gears         3.262043
#  Weight       23.192000
#  Cylinders    -5.355584
#  dtype: float64,
#  '\n',
#  Intercept     9.925271e-08
#  Age_08_04    2.772608e-290
#  KM            1.985300e-56
#  HP            1.496107e-26
#  Gears         1.132207e-03
#  Weight       2.904479e-101
#  Cylinders     9.925271e-08
#  dtype: float64)

# %%
model1.rsquared,model1.rsquared_adj
# Out:
# (0.8627968258548101, 0.86231709447668)

# %%
model_d=smf.ols('Price~Doors',data=data1).fit()

# %%
(model_d.params)
# Out:
# Intercept    7885.005835
# Doors         705.558636
# dtype: float64

# %%
model_d.rsquared,model_d.rsquared_adj
# Out:
# (0.03434555943109785, 0.03367216023962727)

# %%
model_d.pvalues
# Out:
# Intercept    1.094732e-73
# Doors        1.461237e-12
# dtype: float64

# %%
data1.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'HP', 'Doors', 'Cylinders', 'Gears',
#        'Weight'],
#       dtype='object')

# %%
rsq_age=smf.ols('Age_08_04~KM+HP+Doors+Weight+Cylinders',data=data).fit().rsquared
vif_age=1/(1-rsq_age)

rsq_km=smf.ols('KM~Age_08_04+HP+Doors+Weight+Cylinders',data=data).fit().rsquared
vif_km=1/(1-rsq_km)

rsq_hp=smf.ols("HP~Age_08_04+KM+Doors+Gears+Weight+Cylinders",data=data).fit().rsquared
vif_hp=1/(1-rsq_hp)

rsq_d=smf.ols('Doors~Age_08_04+KM+HP+Gears+Weight+Cylinders',data=data).fit().rsquared
vif_d=1/(1-rsq_d)

rsq_g=smf.ols('Gears~Age_08_04+HP+KM+Doors+Weight+Cylinders',data=data).fit().rsquared
vif_g=1/(1-rsq_g)

rsq_w=smf.ols('Weight~Age_08_04+HP+KM+Doors+Gears+Cylinders',data=data).fit().rsquared
vif_w=1/(1-rsq_w)

#rsq_c=smf.ols('Cylinders~Age_08_04+HP+KM+Doors+Gears+Weight',data=data).fit().rsquared
#vif_c=1/(1-rsq_c)

df={"Variables":['Age_08_04','KM','HP','Doors','Gears','Weight','Cylinders'],"VIF":[vif_age,vif_km,vif_hp,vif_d,vif_g,vif_w,vif_c]}
df=pd.DataFrame(df)
df
# Out:
#    Variables       VIF
# 0  Age_08_04  1.873766
# 1         KM  1.614292
# 2         HP  1.214909
# 3      Doors  1.149301
# 4      Gears  1.096501
# 5     Weight  1.508041
# 6  Cylinders  0.000000

# %%
rsq_c
# Out:
# -inf

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q')
import matplotlib.pyplot as plt
plt.title('Normal Residue QQ Plot')
plt.show()

# %%
import numpy as np
a=list(np.where(model.resid>4000))
b=list(np.where(model.resid<-4000))
print(a,b)
# Out:
# [array([ 109,  110,  111,  125,  147,  171,  523, 1058], dtype=int64)] [array([191, 192, 221, 393, 402, 601, 654, 960], dtype=int64)]

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Age_08_04", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "HP", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "KM", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Doors", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Gears", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Weight", fig=fig)
plt.show()

# %%
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance

# %%
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(data)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
(np.argmax(c),np.max(c))
# Out:
# (221, 0.9553151438694948)

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()

# %%
k = data.shape[1]
n = data.shape[0]
leverage_cutoff = 3*((k + 1)/n)

# %%
data1[data1.index.isin([221])]
# Out:
#      Price  Age_08_04     KM   HP  Doors  Cylinders  Gears  Weight
# 221  12450         44  74172  110      5          4      5    1615

# %%
data.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3  ÊTOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#       KM  HP  Doors  Cylinders  Gears  Weight
# 0  46986  90      3          4      5    1165
# 1  72937  90      3          4      5    1165
# 2  41711  90      3          4      5    1165
# 3  48000  90      3          4      5    1165
# 4  38500  90      3          4      5    1170

# %%
data2=data.drop(data.index[[221]],axis=0).reset_index()

# %%
data2=data2.drop(['Id','Model','index'],axis=1)

# %%
data2
# Out:
#       Price  Age_08_04     KM   HP  Doors  Cylinders  Gears  Weight
# 0     13500         23  46986   90      3          4      5    1165
# 1     13750         23  72937   90      3          4      5    1165
# 2     13950         24  41711   90      3          4      5    1165
# 3     14950         26  48000   90      3          4      5    1165
# 4     13750         30  38500   90      3          4      5    1170
# ...     ...        ...    ...  ...    ...        ...    ...     ...
# 1430   7500         69  20544   86      3          4      5    1025
# 1431  10845         72  19000   86      3          4      5    1015
# 1432   8500         71  17016   86      3          4      5    1015
# 1433   7250         70  16916   86      3          4      5    1015
# 1434   6950         76      1  110      5          4      5    1114
#
# [1435 rows x 8 columns]

# %%
final_p_model=smf.ols('Price~Age_08_04+HP+KM+Cylinders+Doors+Gears+Weight',data=data2).fit()

# %%
(final_p_model.rsquared,final_p_model.aic)
# Out:
# (0.8685941460420765, 24696.801453325905)

# %%
final_d_model=smf.ols('Price~Age_08_04+HP+KM+Gears+Weight',data=data2).fit()

# %%
(final_d_model.rsquared,final_d_model.aic)
# Out:
# (0.8685416764053224, 24695.37432659029)

# %%
new_data=pd.DataFrame({'Age_08_04':25,"KM":50000,"HP":85,"Doors":3,"Gears":5,"Weight":1150,"Cylinders":4},index=[1])

# %%
new_data
# Out:
#    Age_08_04     KM  HP  Doors  Gears  Weight  Cylinders
# 1         25  50000  85      3      5    1150          4

# %%
final_d_model.predict(new_data)
# Out:
# 1    15925.952372
# dtype: float64
